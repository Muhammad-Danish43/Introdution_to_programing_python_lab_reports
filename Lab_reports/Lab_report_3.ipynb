# %% [markdown]
# ### **> Resistance Value Check for Short Circuit Safety**
# A resistor with zero value creates a short circuit, which can damage the circuit. Students need to test the resistance before use. Check if the resistance value is zero. If yes, print "Short Circuit", else print "Safe". Store resistance in a variable, use if-else.

# %% [markdown]
# ## Lab Report 3: Control Structures in Python
#
# ### Objective
# The objective of this lab is to learn decision-making and looping structures in Python.
#
# ### Topics Covered
# - if, elif, and else statements
# - for loops
# - while loops
# - Logical conditions

# %%
resistance = 0

if resistance == 0:
    print("Short Circuit")
else:
    print("Safe")
# Out:
# Short Circuit
