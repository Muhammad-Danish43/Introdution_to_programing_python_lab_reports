# %% [markdown]
# ### **> Student Management System Using List and Tuple in Python**
# Scenario:<BR>
# You are designing a small student management system. You need to maintain student data for a class. Each student has a name, a roll number, and a list of grades. The system must allow grade updates but keep roll numbers fixed.<br>
# Tasks:<br>
# 1.	Create a list of student names: ["Ali", "Usman", "Hassan", "Kamran"].<br>
# 2.	Create a tuple of student roll numbers: (101, 102, 103, 104).<br>
# 3.	For each student, create a list of grades (3 subjects) using nested lists:<br>
# Example: [ [85, 90, 78], [88, 92, 80], ... ]<br>
# 4.	Update Ali’s second grade to 95.<br>
# 5.	Add a new grade for Hassan in the fourth subject.<br>
# 6.	Attempt to change Kamran’s roll number and observe what happens. Explain why.<br>
# 7.	Print all students' names with their updated grades in a readable format.<br>

# %% [markdown]
# ## Lab Report 6: Practice and Final Exercises
#
# ### Objective
# The objective of this lab is to apply previously learned Python concepts to practical programming problems.
#
# ### Topics Covered
# - Combined Python concepts
# - Problem-solving using Python
# - Practice programs

# %%
names = ["Ali", "Usman", "Hassan", "Kamran"]
roll_numbers = (101, 102, 103, 104)
grades = [
    [85, 95, 78],
    [88, 92, 80],
    [75, 85, 70, 88],
    [90, 88, 92]
]

print("Students and their grades:")

print(names[0], "(Roll No:", roll_numbers[0], ")-> Grades:", grades[0])
print(names[1], "(Roll No:", roll_numbers[1], ")-> Grades:", grades[1])
print(names[2], "(Roll No:", roll_numbers[2], ")-> Grades:", grades[2])
print(names[3], "(Roll No:", roll_numbers[3], ")-> Grades:", grades[3])
# Out:
# Students and their grades:
# Ali (Roll No: 101 )-> Grades: [85, 95, 78]
# Usman (Roll No: 102 )-> Grades: [88, 92, 80]
# Hassan (Roll No: 103 )-> Grades: [75, 85, 70, 88]
# Kamran (Roll No: 104 )-> Grades: [90, 88, 92]
