# %% [markdown]
# ### **> Calculation of Series Resistance Using Python Function**

# %%
def series(resistances: list | tuple) -> float:
    """This function returns total series resistance"""
    return sum(resistances)

print(series.__annotations__)
# Out:
# {'resistances': list | tuple, 'return': <class 'float'>}
